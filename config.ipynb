# %% [markdown]
# <a href="https://colab.research.google.com/github/fanat503/Induction-Heads-Tinystories/blob/main/config.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
B = 4
T = 1024
grad_accum_steps = 32
max_steps = 20000
warmup_steps = 200
max_lr = 6e-4
min_lr = 6e-5

project_dir = '***'
checkpoint_path = '***'
